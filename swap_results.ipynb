# %% [markdown]
# # Extracation and Analysis of the results from SWAP output files

# %%
#required libraries 
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
import csv
import os

# %%
# required SWAP built functions

# %%
import sys
sys.path.append("swap_pyfunctions")
from IncResults import Incresults
from SwbResults import Swbresults
from StrResults import Strresults
from CrpResults import Crpresults
from DrfResults import Drfresults
from VapResults import Vapresults

# %%
#define time conditions of the results to be visualised 
dat1="1/1/2002"
dat2="30/12/2003"
dateleg="30/6/2003"
nameSC=['out'] # if you indicate to two different out fodlers (e.g. one for controlled drainage and one for regular drainage, nameSC=['CD_out','RD_out']) the code plot and analyse both  
#CDstart="2003-05-02"
#CDend="2003-05-30"
#ftsz=14
# what kind of variable do you wanna ploy, watercontent (wcontent), pressurehead (phead), concentartaion (solute1) etc
desvar="phead" 
# for which depth of soil profile do you wanna plot desvar
dmax=140
#xx={}
#nameSC

# %%
for k,j in enumerate(nameSC):
    fileSWB="Ostend/"+j+"/result.swb" 
    fileINC="Ostend/"+j+"/result.inc"
    fileDRF="Ostend/"+j+"/result.drf"
    fileVAP="Ostend/"+j+"/result.vap"

    dfSW, dfInc=Swbresults(fileSWB,fileINC,1989, j,dat1,dat2,controldrain="TRUE",ylim1=-150, arbitvar="DRORR")
    dfDRF, dfInc=Drfresults(fileDRF,fileINC,1989, j,dat1,dat2,ylim1=-150)
    Vapresults(fileVAP,desvar, j,"1/1/2002","30/12/2003",dmax)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3438: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# C:\Users\amehmandoostkotlar\OneDrive - ILVO\OPEIL\SWAP\Jupyter\swap-test\swap_pyfunctions\SwbResults.py:57: UserWarning: Parsing '30/12/2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfplot=df[df['Date'].between(pd.to_datetime(firstdate), pd.to_datetime(secdate))]
# C:\Users\amehmandoostkotlar\OneDrive - ILVO\OPEIL\SWAP\Jupyter\swap-test\swap_pyfunctions\SwbResults.py:58: UserWarning: Parsing '30/12/2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dfIncplot=dfInc[dfInc['Date'].between(pd.to_datetime(firstdate), pd.to_datetime(secdate))]
# ...
